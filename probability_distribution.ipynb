# %%
from scipy.stats import binom

# %%
binom.pmf(n=12,k=1,p=0.5)
# Out:
# np.float64(0.0029296875000000004)

# %%
binom.cdf(n=12,k=2,p=0.5)
# Out:
# np.float64(0.019287109375)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
k = np.random.normal(loc=0,scale=2,size=65)
plt.hist(k,bins=25)
plt.title("normal distribution")
plt.show()

# %%
sns.histplot(k,kde=True)
plt.title("bell curve")
plt.show()
