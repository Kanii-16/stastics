# %%
from scipy.stats import binom

# %%
# 1.online shopping
n=12
p=0.9

# %%
# exactly 10
binom.pmf(k=10,n=12,p=0.9)
# Out:
# np.float64(0.23012777046599997)

# %%
# atleast 11
binom.sf(11,n=12,p=0.9)
# Out:
# np.float64(0.3765727153080001)

# %%
# fewer than
binom.cdf(9,n=12,p=0.9)
# Out:
# np.float64(0.11086997774499993)

# %%
# 2.campus placement
n=15
p=0.65

# %%
# exactly 12
binom.pmf(k=12,n=15,p=0.65)
# Out:
# np.float64(0.11096239180419934)

# %%
# atleast 10
binom.sf(10,n=12,p=0.65)
# Out:
# np.float64(0.04244129839394264)

# %%
# expected number
binom.mean(n=12,p=0.65)
# Out:
# np.float64(7.800000000000001)

# %%
#.3.Bank loan approval
n=20
p=0.7

# %%
# exactly
binom.pmf(k=16,n=20,p=0.7)
# Out:
# np.float64(0.1304209743738704)

# %%
# more than
binom.sf(18,n=20,p=0.7)
# Out:
# np.float64(0.007637259774199997)

# %%
# mean
binom.mean(n=20,p=0.7)
# Out:
# np.float64(14.0)

# %%
# variance
binom.var(n=20,p=0.7)
# Out:
# np.float64(4.200000000000001)

# %%
# 4. cricket match
n = 10
p = 0.4

# %%
# exactly
binom.pmf(k=5,n=10,p=0.4)
# Out:
# np.float64(0.20065812479999992)

# %%
# atleast
binom.sf(7,n=20,p=0.4)
# Out:
# np.float64(0.41589293755753554)

# %%
# no. of probability
binom.pmf(0,n=20,p=0.4)
# Out:
# np.float64(3.6561584400629835e-05)

# %%
# 5.bulb quality check
n = 30
p = 0.4

# %%
# exactly
binom.pmf(k=2,n=30,p=0.4)
# Out:
# np.float64(4.274095781267516e-05)

# %%
# none
binom.pmf(0,n=30,p=0.4)
# Out:
# np.float64(2.21073919720733e-07)

# %%
# atleast
binom.sf(1,n=30,p=0.4)
# Out:
# np.float64(4.6425523141353955e-06)

# %%
# 6. email marketing
n = 18
p = 0.25

# %%
# exactly
binom.pmf(k=6,n=18,p=0.25)
# Out:
# np.float64(0.1435644040466287)

# %%
# altleast
binom.sf(4,n=18,p=0.25)
# Out:
# np.float64(0.5186693304567598)

# %%
# expected number
binom.mean(n=18,p=0.25)
# Out:
# np.float64(4.5)

# %%
# 7.hospital vaccination
n= 25
p= 0.95

# %%
# exactly
binom.pmf(k=24,p=0.95,n=25)
# Out:
# np.float64(0.3649862804234658)

# %%
 # probability respond
binom.pmf(k=25,n=25,p=0.95)
# Out:
# np.float64(0.27738957312183377)

# %%
# fewer than
binom.cdf(23,n=25,p=0.95)
# Out:
# np.float64(0.3576241464547004)

# %%
# 8.software testing
n = 20
p = 0.92

# %%
# exactly
binom.pmf(k=18,n=20,p=0.92)
# Out:
# np.float64(0.2710906052244336)

# %%
# all testcase
binom.pmf(20,n=20,p=0.92)
# Out:
# np.float64(0.1886933291627967)

# %%
# atleast
binom.sf(19,n=20,p=0.92)
# Out:
# np.float64(0.18869332916279669)

# %%
# 9.students attendance
p = 0.8
n = 15

# %%
# exactly
binom.pmf(k=12,n=15,p=0.8)
# Out:
# np.float64(0.25013889531904)

# %%
# more than
binom.sf(10,n=15,p=0.8)
# Out:
# np.float64(0.8357662760632321)

# %%
# expected
binom.mean(n=15,p=0.8)
# Out:
# np.float64(12.0)

# %%
# 10.mobile app installation
n = 25
p = 0.3

# %%
# exactly
binom.pmf(k=8,n=25,p=0.3)
# Out:
# np.float64(0.1650795811315247)

# %%
# atleast
binom.sf(10,n=25,p=0.3)
# Out:
# np.float64(0.09780001112173187)

# %%
# fewer than
binom.cdf(5,n=25,p=0.3)
# Out:
# np.float64(0.19348844208806493)
